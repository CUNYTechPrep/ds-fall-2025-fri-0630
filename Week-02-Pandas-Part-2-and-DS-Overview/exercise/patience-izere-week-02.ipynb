# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.

import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).

food_data_set_path = '/workspaces/ds-fall-2025-fri-0630/Week-02-Pandas-Part-2-and-DS-Overview/data/food_coded.csv'
df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
print("Number of rows and columns:", df_food.shape)
# Out:
# Number of rows and columns: (125, 61)

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.

print("\nColumn names and data types:")
print(df_food.dtypes)
# Out:
# Column names and data types:
# GPA                  object
# Gender                int64
# breakfast             int64
# calories_chicken      int64
# calories_day        float64
#                      ...
# type_sports          object
# veggies_day           int64
# vitamins              int64
# waffle_calories       int64
# weight               object
# Length: 61, dtype: object

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.
selected_columns = ['calories_day', 'weight', 'Gender']
df_selected = df_food[selected_columns]

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.

print("\nNaN values in selected columns:")
print(df_selected.isna().sum())
# Out:
# NaN values in selected columns:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.

df_cleaned = df_selected.dropna()

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.

df_selected['calories_day'] = pd.to_numeric(df_selected['calories_day'], errors='coerce')
# Out:
# /tmp/ipykernel_8494/2822426040.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['calories_day'] = pd.to_numeric(df_selected['calories_day'], errors='coerce')

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!

output_path = '/workspaces/ds-fall-2025-fri-0630/Week-02-Pandas-Part-2-and-DS-Overview/data/food_cleaned.csv'
df_cleaned.to_csv(output_path, index=False)
print("\nCleaned dataset saved to 'food_cleaned.csv'.")
# Out:
# Cleaned dataset saved to 'food_cleaned.csv'.

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).
path= '/workspaces/ds-fall-2025-fri-0630/Week-02-Pandas-Part-2-and-DS-Overview/data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv'
df_salary =pd.read_csv(path, sep='\t', encoding='utf-8')

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.

rows, cols = df_salary.shape
print(f"Loaded {rows} rows and {cols} columns")
# Out:
# Loaded 28062 rows and 18 columns

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.

print(df_salary.dtypes)
# Out:
# timestamp                       object
# age                             object
# industry                        object
# title                           object
# title_context                   object
# salary                          object
# additional_compensation        float64
# currency                        object
# other_currency                  object
# salary_context                  object
# country                         object
# state                           object
# city                            object
# total_yoe                       object
# field_yoe                       object
# highest_education_completed     object
# gender                          object
# race                            object
# dtype: object

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race

df_salary.columns = [
    "timestamp",
    "age",
    "industry",
    "title",
    "title_context",
    "salary",
    "additional_compensation",
    "currency",
    "other_currency",
    "salary_context",
    "country",
    "state",
    "city",
    "total_yoe",
    "field_yoe",
    "highest_education_completed",
    "gender",
    "race"
]

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.

industry_counts = df_salary["industry"].value_counts()
print(industry_counts)
# Out:
# industry
# Computing or Tech                        4699
# Education (Higher Education)             2464
# Nonprofits                               2419
# Health care                              1896
# Government and Public Administration     1889
#                                          ...
# Warehousing                                 1
# Education (Early Childhood Education)       1
# SAAS                                        1
# Health and Safety                           1
# Aerospace Manufacturing                     1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)

tech_label = industry_counts.index[0]
df_salary_tech = df_salary[df_salary["industry"] == tech_label]

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 

print(df_salary_tech["industry"].unique())
# Out:
# ['Computing or Tech']

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!

df_salary_tech_usd = df_salary_tech[df_salary_tech["currency"] == "USD"]

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.

country_counts = df_salary_tech_usd["country"].value_counts()
print(country_counts.head(10))
# Out:
# country
# US                           3538
# United States                  68
# USA                            56
# United states                  23
# United States of America        7
# Israel                          5
# Canada                          4
# United State of America         2
# U.S.                            2
# UnitedStates                    2
# Name: count, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.

top5 = df_salary_tech_usd['country'].value_counts().head(5).index.tolist()
df_salary_tech_usd['country'] = df_salary_tech_usd['country'].replace(top5, 'US')

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.

print("After top-5 → 'US':")
print(df_salary_tech_usd['country'].value_counts(), "\n")
# Out:
# After top-5 → 'US':
# country
# US                          3705
# Unite States                   2
# Usa                            2
# Spain                          2
# United States Of America       2
# Brazil                         2
# India                          2
# UnitedStates                   2
# Australia                      2
# U.S                            2
# United States of america       2
# U.S.A                          2
# France                         2
# New Zealand                    2
# Poland                         2
# united States                  2
# United Kingdom                 2
# United Stated                  1
# United State                   1
# U.s.                           1
#  US                            1
# Uniyed states                  1
# America                        1
# US                             1
# Puerto Rico                    1
# Uruguay                        1
# Singapore                      1
# ...

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.

us_aliases = [
    'USA', 'United States', 'U.S.A.', 'US of A','Us','us', 'united states', 'United States of america'
    'America', 'United States of America', 'usa', 'Usa', 'United STates'
]
df_salary_tech_usd['country'] = df_salary_tech_usd['country'] \
    .replace(us_aliases, 'US')

# %%
# BONUS CREDIT: 

print("After alias cleanup:")
print(df_salary_tech_usd['country'].value_counts(), "\n")
# Out:
# After alias cleanup:
# country
# US                          3705
# Unite States                   2
# Usa                            2
# Spain                          2
# United States Of America       2
# Brazil                         2
# India                          2
# UnitedStates                   2
# Australia                      2
# U.S                            2
# United States of america       2
# U.S.A                          2
# France                         2
# New Zealand                    2
# Poland                         2
# united States                  2
# United Kingdom                 2
# United Stated                  1
# United State                   1
# U.s.                           1
#  US                            1
# Uniyed states                  1
# America                        1
# US                             1
# Puerto Rico                    1
# Uruguay                        1
# Singapore                      1
# ...

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.

state_summary = (
    df_salary_tech_usd.groupby('state')['salary'].agg(['min','mean','max'])
      .sort_values('mean', ascending=False)
)
print("All‐time state summary:")
print(state_summary, "\n")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1943, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1942 try:
# -> 1943     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1944 except Exception as err:
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
# ...

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
# Fix it.

df_salary_tech_usd['salary'] = pd.to_numeric(
    df_salary_tech_usd['salary'], errors='coerce'
)
df_salary_tech_usd = df_salary_tech_usd.dropna(subset=['salary'])

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!

state_summary = (
    df_salary_tech_usd.groupby('state')['salary']
      .agg(['min','mean','max'])
      .sort_values('mean', ascending=False)
)
print("All‐time state summary:")
print(state_summary, "\n")
# Out:
# All‐time state summary:
#                                      min           mean        max
# state
# Michigan, Texas, Washington     340000.0  340000.000000   340000.0
# Florida                          28800.0  210711.000000  2600000.0
# California, Oregon              200000.0  200000.000000   200000.0
# California, Colorado            176000.0  176000.000000   176000.0
# Delaware                        169000.0  169000.000000   169000.0
# Connecticut                      68000.0  161610.000000   270000.0
# California                           0.0  153286.988827   520000.0
# New York                         14000.0  146594.112150   590000.0
# Wisconsin                            1.0  145806.888889   920000.0
# District of Columbia             59000.0  142923.076923   200000.0
# New Jersey, New York            135000.0  137500.000000   140000.0
# Ohio                             42000.0  137066.666667   954000.0
# Washington                          72.0  136923.916667   300000.0
# ...

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.
df_salary_recent = df_salary_tech_usd['timestamp'] = pd.to_datetime(
    df_salary_tech_usd['timestamp'],
    infer_datetime_format=True,
    errors='coerce'
)
mask = df_salary_tech_usd['timestamp'].dt.year.isin([2021, 2022])
df_salary_recent = df_salary_tech_usd[mask]

recent_state_summary = (
    df_salary_recent.groupby('state')['salary']
      .agg(['min','mean','max'])
      .sort_values('mean', ascending=False)
)
print("2021–2022 state summary:")
print(recent_state_summary)
# Out:
# 2021–2022 state summary:
#                                      min           mean       max
# state
# Michigan, Texas, Washington     340000.0  340000.000000  340000.0
# California, Oregon              200000.0  200000.000000  200000.0
# California, Colorado            176000.0  176000.000000  176000.0
# Delaware                        169000.0  169000.000000  169000.0
# Connecticut                      68000.0  161610.000000  270000.0
# California                           0.0  153754.893258  520000.0
# New York                         14000.0  147363.867925  590000.0
# Wisconsin                            1.0  145806.888889  920000.0
# District of Columbia             59000.0  142923.076923  200000.0
# Ohio                             42000.0  141894.117647  954000.0
# Alabama                          52000.0  138000.000000  350000.0
# New Jersey, New York            135000.0  137500.000000  140000.0
# Washington                          72.0  137427.774648  300000.0
# ...

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %%
import pandas as pd

# 1. Start with df_salary (all industries, renamed columns)
df = df_salary.copy()

# 2. Coerce salary → numeric; drop invalid
df['salary'] = pd.to_numeric(df['salary'], errors='coerce')
df = df.dropna(subset=['salary'])

# 3. Restrict to USD (we still haven’t converted EUR/GBP…)
df = df[df['currency'] == 'USD']

# 4. Parse timestamps and drop bad rows
df['timestamp'] = pd.to_datetime(df['timestamp'], infer_datetime_format=True, errors='coerce')
df = df.dropna(subset=['timestamp'])

# 5. Now group by state and compute min/mean/max
state_summary = (
    df.groupby('state')['salary'].agg(min='min', mean='mean', max='max')
      .sort_values('mean', ascending=False)
)

state_summary
# Out:
# /tmp/ipykernel_8494/356881843.py:14: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['timestamp'] = pd.to_datetime(df['timestamp'], infer_datetime_format=True, errors='coerce')
#                                         min       mean         max
# state
# Alabama, South Carolina           5000000.0  5000000.0   5000000.0
# Alaska                              47840.0   737319.2  10000000.0
# Michigan, Texas, Washington        340000.0   340000.0    340000.0
# California, Oregon                 200000.0   200000.0    200000.0
# California, Colorado               176000.0   176000.0    176000.0
# ...                                     ...        ...         ...
# District of Columbia, Washington    35000.0    35000.0     35000.0
# ...

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %%
# Use the existing `state_summary` from above
styled = (
    state_summary.style
      .format({
         'min': '${:,.2f}',
         'mean': '${:,.2f}',
         'max': '${:,.2f}'
      }).set_caption("All-Time Salary by State (USD)")
)

styled
# Out:
# <style type="text/css">
# </style>
# <table id="T_710f0">
#   <caption>All-Time Salary by State (USD)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_710f0_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_710f0_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_710f0_level0_col2" class="col_heading level0 col2" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >state</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_710f0_level0_row0" class="row_heading level0 row0" >Alabama, South Carolina</th>
#       <td id="T_710f0_row0_col0" class="data row0 col0" >$5,000,000.00</td>
#       <td id="T_710f0_row0_col1" class="data row0 col1" >$5,000,000.00</td>
# ...

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %%
# Filter to rows where state does NOT contain a comma
df_single_state = df[~df['state'].str.contains(',', na=False)].copy()

# Sanity check: no commas anywhere
assert not df_single_state['state'].str.contains(',', na=False).any()

# Recompute the summary
single_state_summary = (
    df_single_state.groupby('state')['salary'].agg(min='min', mean='mean', max='max')
      .sort_values('mean', ascending=False)
)

single_state_summary
# Out:
#                           min           mean         max
# state
# Alaska                47840.0  737319.200000  10000000.0
# New Jersey            14850.0  130764.608333   5000044.0
# California                0.0  113445.358974    520000.0
# District of Columbia     40.0  109850.159817   1250000.0
# New York                 80.0  106658.932886    590000.0
# Delaware              35000.0  103455.555556    220000.0
# Massachusetts           155.0   99883.125628    400000.0
# Washington               72.0   98032.896552    300000.0
# Virginia                 57.0   96247.442922   1300000.0
# Florida                 150.0   92868.042553   2600000.0
# Utah                  28000.0   91167.660000    576000.0
# Oregon                    0.0   90191.924419    230000.0
# Maryland                  0.0   89189.863354    353200.0
# Texas                     0.0   89089.335121    300000.0
# Connecticut               0.0   88467.536232    270000.0
# ...

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)

# %%
# Define desired quantiles
qs = [0, .05, .25, .5, .75, .95, 1.0]

# Group and aggregate
quantile_summary = (
    df_single_state.groupby('state')['salary']
      .agg(
         count='count',
         q0=lambda x: x.quantile(qs[0]),
         q5=lambda x: x.quantile(qs[1]),
         q25=lambda x: x.quantile(qs[2]),
         q50=lambda x: x.quantile(qs[3]),
         q75=lambda x: x.quantile(qs[4]),
         q95=lambda x: x.quantile(qs[5]),
         q100=lambda x: x.quantile(qs[6]),
      ).sort_values('q50', ascending=False)  # sort by median
)

quantile_summary
# Out:
#                       count       q0        q5       q25       q50       q75  \
# state
# California              741      0.0  40000.00  70000.00  103000.0  149000.0
# District of Columbia    219     40.0  46850.00  71000.00   97000.0  126307.0
# Delaware                  9  35000.0  42840.00  65000.00   92500.0  120000.0
# New York                596     80.0  40000.00  65000.00   91500.0  135000.0
# Washington              290     72.0  39000.00  65000.00   87000.0  125000.0
# Massachusetts           398    155.0  45647.65  65000.00   86301.5  124950.0
# Connecticut              69      0.0  43000.00  65000.00   84500.0  100000.0
# Maryland                161      0.0  33000.00  58560.00   83000.0  110000.0
# Virginia                219     57.0  36080.00  58325.00   83000.0  111000.0
# Colorado                159     65.0  38422.00  62000.00   82000.0  105000.0
# Oregon                  172      0.0  39016.80  58150.00   80500.0  115000.0
# ...
